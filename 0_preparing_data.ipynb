# %% [markdown]
# # Preparing a Dataset
# - How does the dataset handle invalid values
# - What do we want to do with null values
# - Do we want to summarise, group, or filter data

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('marketing_data.csv')

# %%
df.head()
# Out:
#       ID  Year_Birth   Education Marital_Status      Income   Kidhome  \
# 0   1826        1970  Graduation       Divorced  $84,835.00         0
# 1      1        1961  Graduation         Single  $57,091.00         0
# 2  10476        1958  Graduation        Married  $67,267.00         0
# 3   1386        1967  Graduation       Together  $32,474.00         1
# 4   5371        1989  Graduation         Single  $21,474.00         1
#
#    Teenhome Dt_Customer  Recency  MntWines  ...  NumStorePurchases  \
# 0         0     6/16/14        0       189  ...                  6
# 1         0     6/15/14        0       464  ...                  7
# 2         1     5/13/14        0       134  ...                  5
# 3         1     5/11/14        0        10  ...                  2
# 4         0      4/8/14        0         6  ...                  2
#
#    NumWebVisitsMonth  AcceptedCmp3  AcceptedCmp4  AcceptedCmp5  AcceptedCmp1  \
# 0                  1             0             0             0             0
# 1                  5             0             0             0             0
# 2                  2             0             0             0             0
# 3                  7             0             0             0             0
# 4                  7             1             0             0             0
#
#    AcceptedCmp2  Response  Complain  Country
# 0             0         1         0       SP
# 1             1         1         0       CA
# 2             0         0         0       US
# 3             0         0         0      AUS
# 4             0         1         0       SP
#
# [5 rows x 28 columns]

# %%
df.shape
# Out:
# (2240, 28)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2240 entries, 0 to 2239
# Data columns (total 28 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   ID                   2240 non-null   int64
#  1   Year_Birth           2240 non-null   int64
#  2   Education            2240 non-null   object
#  3   Marital_Status       2240 non-null   object
#  4    Income              2216 non-null   object
#  5   Kidhome              2240 non-null   int64
#  6   Teenhome             2240 non-null   int64
#  7   Dt_Customer          2240 non-null   object
#  8   Recency              2240 non-null   int64
#  9   MntWines             2240 non-null   int64
#  10  MntFruits            2240 non-null   int64
#  11  MntMeatProducts      2240 non-null   int64
#  12  MntFishProducts      2240 non-null   int64
#  13  MntSweetProducts     2240 non-null   int64
#  14  MntGoldProds         2240 non-null   int64
#  15  NumDealsPurchases    2240 non-null   int64
#  16  NumWebPurchases      2240 non-null   int64
#  17  NumCatalogPurchases  2240 non-null   int64
#  18  NumStorePurchases    2240 non-null   int64
#  19  NumWebVisitsMonth    2240 non-null   int64
#  20  AcceptedCmp3         2240 non-null   int64
#  21  AcceptedCmp4         2240 non-null   int64
#  22  AcceptedCmp5         2240 non-null   int64
#  23  AcceptedCmp1         2240 non-null   int64
#  24  AcceptedCmp2         2240 non-null   int64
#  25  Response             2240 non-null   int64
#  26  Complain             2240 non-null   int64
#  27  Country              2240 non-null   object
# dtypes: int64(23), object(5)
# memory usage: 490.1+ KB

# %% [markdown]
# No `Null` values, and mix of `objects` and `int64`

# %%
# If there were Null values
df.fillna('None', inplace=True)

# %%
df.head()
# Out:
#       ID  Year_Birth   Education Marital_Status      Income   Kidhome  \
# 0   1826        1970  Graduation       Divorced  $84,835.00         0
# 1      1        1961  Graduation         Single  $57,091.00         0
# 2  10476        1958  Graduation        Married  $67,267.00         0
# 3   1386        1967  Graduation       Together  $32,474.00         1
# 4   5371        1989  Graduation         Single  $21,474.00         1
#
#    Teenhome Dt_Customer  Recency  MntWines  ...  NumStorePurchases  \
# 0         0     6/16/14        0       189  ...                  6
# 1         0     6/15/14        0       464  ...                  7
# 2         1     5/13/14        0       134  ...                  5
# 3         1     5/11/14        0        10  ...                  2
# 4         0      4/8/14        0         6  ...                  2
#
#    NumWebVisitsMonth  AcceptedCmp3  AcceptedCmp4  AcceptedCmp5  AcceptedCmp1  \
# 0                  1             0             0             0             0
# 1                  5             0             0             0             0
# 2                  2             0             0             0             0
# 3                  7             0             0             0             0
# 4                  7             1             0             0             0
#
#    AcceptedCmp2  Response  Complain  Country
# 0             0         1         0       SP
# 1             1         1         0       CA
# 2             0         0         0       US
# 3             0         0         0      AUS
# 4             0         1         0       SP
#
# [5 rows x 28 columns]

# %%
df.describe()
# Out:
#                  ID   Year_Birth      Kidhome     Teenhome      Recency  \
# count   2240.000000  2240.000000  2240.000000  2240.000000  2240.000000
# mean    5592.159821  1968.805804     0.444196     0.506250    49.109375
# std     3246.662198    11.984069     0.538398     0.544538    28.962453
# min        0.000000  1893.000000     0.000000     0.000000     0.000000
# 25%     2828.250000  1959.000000     0.000000     0.000000    24.000000
# 50%     5458.500000  1970.000000     0.000000     0.000000    49.000000
# 75%     8427.750000  1977.000000     1.000000     1.000000    74.000000
# max    11191.000000  1996.000000     2.000000     2.000000    99.000000
#
#           MntWines    MntFruits  MntMeatProducts  MntFishProducts  \
# count  2240.000000  2240.000000      2240.000000      2240.000000
# mean    303.935714    26.302232       166.950000        37.525446
# std     336.597393    39.773434       225.715373        54.628979
# min       0.000000     0.000000         0.000000         0.000000
# 25%      23.750000     1.000000        16.000000         3.000000
# 50%     173.500000     8.000000        67.000000        12.000000
# 75%     504.250000    33.000000       232.000000        50.000000
# max    1493.000000   199.000000      1725.000000       259.000000
#
#        MntSweetProducts  ...  NumCatalogPurchases  NumStorePurchases  \
# count       2240.000000  ...          2240.000000        2240.000000
# mean          27.062946  ...             2.662054           5.790179
# std           41.280498  ...             2.923101           3.250958
# min            0.000000  ...             0.000000           0.000000
# 25%            1.000000  ...             0.000000           3.000000
# 50%            8.000000  ...             2.000000           5.000000
# 75%           33.000000  ...             4.000000           8.000000
# max          263.000000  ...            28.000000          13.000000
#
#        NumWebVisitsMonth  AcceptedCmp3  AcceptedCmp4  AcceptedCmp5  \
# count        2240.000000   2240.000000   2240.000000   2240.000000
# mean            5.316518      0.072768      0.074554      0.072768
# std             2.426645      0.259813      0.262728      0.259813
# min             0.000000      0.000000      0.000000      0.000000
# 25%             3.000000      0.000000      0.000000      0.000000
# 50%             6.000000      0.000000      0.000000      0.000000
# 75%             7.000000      0.000000      0.000000      0.000000
# max            20.000000      1.000000      1.000000      1.000000
#
#        AcceptedCmp1  AcceptedCmp2     Response     Complain
# count   2240.000000   2240.000000  2240.000000  2240.000000
# mean       0.064286      0.013393     0.149107     0.009375
# std        0.245316      0.114976     0.356274     0.096391
# min        0.000000      0.000000     0.000000     0.000000
# 25%        0.000000      0.000000     0.000000     0.000000
# 50%        0.000000      0.000000     0.000000     0.000000
# 75%        0.000000      0.000000     0.000000     0.000000
# max        1.000000      1.000000     1.000000     1.000000
#
# [8 rows x 23 columns]

# %% [markdown]
# Columns that may be using `0` instead of `Null` values are:
# - MntWines
# - MntMeatProducts
#
# Because they have `0` value minimums and then a much larger number `25%` quartile
#
# Not `ID` or `Recency` as they seem to start from 0 and increment up

# %%
df = df.loc[~(df[df.columns[9:11]] == 0).any(axis=1)]

# %%
df.describe()
# Out:
#                  ID   Year_Birth      Kidhome     Teenhome      Recency  \
# count   1832.000000  1832.000000  1832.000000  1832.000000  1832.000000
# mean    5558.670306  1969.017467     0.404476     0.465066    49.576419
# std     3253.838184    12.057514     0.522191     0.542948    29.113305
# min        0.000000  1899.000000     0.000000     0.000000     0.000000
# 25%     2790.000000  1959.000000     0.000000     0.000000    24.000000
# 50%     5348.000000  1970.000000     0.000000     0.000000    50.000000
# 75%     8407.750000  1978.000000     1.000000     1.000000    75.000000
# max    11191.000000  1996.000000     2.000000     2.000000    99.000000
#
#           MntWines    MntFruits  MntMeatProducts  MntFishProducts  \
# count  1832.000000  1832.000000      1832.000000      1832.000000
# mean    320.595524    32.143013       189.387009        43.205240
# std     334.756313    41.796420       233.588124        56.910418
# min       1.000000     1.000000         1.000000         0.000000
# 25%      28.000000     4.000000        21.000000         4.000000
# 50%     205.000000    14.000000        91.500000        17.000000
# 75%     526.000000    43.000000       271.250000        62.000000
# max    1493.000000   199.000000      1725.000000       259.000000
#
#        MntSweetProducts  ...  NumCatalogPurchases  NumStorePurchases  \
# count       1832.000000  ...          1832.000000        1832.000000
# mean          31.166485  ...             2.920852           6.065502
# std           43.078277  ...             2.954370           3.267447
# min            0.000000  ...             0.000000           0.000000
# 25%            3.000000  ...             1.000000           3.000000
# 50%           12.000000  ...             2.000000           5.000000
# 75%           41.000000  ...             5.000000           8.000000
# max          263.000000  ...            28.000000          13.000000
#
#        NumWebVisitsMonth  AcceptedCmp3  AcceptedCmp4  AcceptedCmp5  \
# count        1832.000000   1832.000000   1832.000000   1832.000000
# mean            5.122271      0.072598      0.069323      0.082969
# std             2.473962      0.259547      0.254072      0.275911
# min             0.000000      0.000000      0.000000      0.000000
# 25%             3.000000      0.000000      0.000000      0.000000
# 50%             5.000000      0.000000      0.000000      0.000000
# 75%             7.000000      0.000000      0.000000      0.000000
# max            20.000000      1.000000      1.000000      1.000000
#
#        AcceptedCmp1  AcceptedCmp2     Response     Complain
# count   1832.000000   1832.000000  1832.000000  1832.000000
# mean       0.068231      0.011463     0.161026     0.009279
# std        0.252211      0.106479     0.367655     0.095908
# min        0.000000      0.000000     0.000000     0.000000
# 25%        0.000000      0.000000     0.000000     0.000000
# 50%        0.000000      0.000000     0.000000     0.000000
# 75%        0.000000      0.000000     0.000000     0.000000
# max        1.000000      1.000000     1.000000     1.000000
#
# [8 rows x 23 columns]

# %%
df.groupby('Response').mean()
# Out:
#                    ID   Year_Birth   Kidhome  Teenhome    Recency    MntWines  \
# Response
# 0         5579.655823  1968.970722  0.421601  0.502928  52.310995  283.629148
# 1         5449.332203  1969.261017  0.315254  0.267797  35.328814  513.196610
#
#           MntFruits  MntMeatProducts  MntFishProducts  MntSweetProducts  ...  \
# Response                                                                 ...
# 0         30.010410       164.991542        40.520494         29.149642  ...
# 1         43.254237       316.491525        57.193220         41.674576  ...
#
#           NumWebPurchases  NumCatalogPurchases  NumStorePurchases  \
# Response
# 0                4.119063             2.634353           6.043591
# 1                5.155932             4.413559           6.179661
#
#           NumWebVisitsMonth  AcceptedCmp3  AcceptedCmp4  AcceptedCmp5  \
# Response
# 0                  5.122316      0.042290      0.049447      0.042941
# 1                  5.122034      0.230508      0.172881      0.291525
#
#           AcceptedCmp1  AcceptedCmp2  Complain
# Response
# 0             0.034483      0.002602  0.009759
# 1             0.244068      0.057627  0.006780
#
# [2 rows x 22 columns]

# %%
df.groupby('Response').agg({"AcceptedCmp3": "mean", "AcceptedCmp4": "median", "AcceptedCmp5": "sum"})
# Out:
#           AcceptedCmp3  AcceptedCmp4  AcceptedCmp5
# Response
# 0             0.042290             0            66
# 1             0.230508             0            86

# %%
df.groupby("Response").agg(["mean", "median"])
# Out:
#                    ID          Year_Birth          Kidhome         Teenhome  \
#                  mean median         mean median      mean median      mean
# Response
# 0         5579.655823   5396  1968.970722   1970  0.421601      0  0.502928
# 1         5449.332203   5204  1969.261017   1971  0.315254      0  0.267797
#
#                    Recency         ... AcceptedCmp4        AcceptedCmp5  \
#          median       mean median  ...         mean median         mean
# Response                           ...
# 0             0  52.310995     53  ...     0.049447      0     0.042941
# 1             0  35.328814     30  ...     0.172881      0     0.291525
#
#                 AcceptedCmp1        AcceptedCmp2         Complain
#          median         mean median         mean median      mean median
# Response
# 0             0     0.034483      0     0.002602      0  0.009759      0
# 1             0     0.244068      0     0.057627      0  0.006780      0
#
# [2 rows x 44 columns]

# %%
df1 = df[df["Response"] == 1]

# %%
df0 = df[df["Response"] == 0]

# %%
df1.head()
# Out:
#      ID  Year_Birth   Education Marital_Status      Income   Kidhome  \
# 0  1826        1970  Graduation       Divorced  $84,835.00         0
# 1     1        1961  Graduation         Single  $57,091.00         0
# 4  5371        1989  Graduation         Single  $21,474.00         1
# 5  7348        1958         PhD         Single  $71,691.00         0
# 6  4073        1954    2n Cycle        Married  $63,564.00         0
#
#    Teenhome Dt_Customer  Recency  MntWines  ...  NumStorePurchases  \
# 0         0     6/16/14        0       189  ...                  6
# 1         0     6/15/14        0       464  ...                  7
# 4         0      4/8/14        0         6  ...                  2
# 5         0     3/17/14        0       336  ...                  5
# 6         0     1/29/14        0       769  ...                  7
#
#    NumWebVisitsMonth  AcceptedCmp3  AcceptedCmp4  AcceptedCmp5  AcceptedCmp1  \
# 0                  1             0             0             0             0
# 1                  5             0             0             0             0
# 4                  7             1             0             0             0
# 5                  2             0             0             0             0
# 6                  6             1             0             0             0
#
#    AcceptedCmp2  Response  Complain  Country
# 0             0         1         0       SP
# 1             1         1         0       CA
# 4             0         1         0       SP
# 5             0         1         0       SP
# 6             0         1         0      GER
#
# [5 rows x 28 columns]

# %%
df0.head()
# Out:
#        ID  Year_Birth   Education Marital_Status      Income   Kidhome  \
# 2   10476        1958  Graduation        Married  $67,267.00         0
# 10   2079        1947    2n Cycle        Married  $81,044.00         0
# 11   5642        1979      Master       Together  $62,499.00         1
# 13   2964        1981  Graduation        Married  $26,872.00         0
# 14  10311        1969  Graduation        Married   $4,428.00         0
#
#     Teenhome Dt_Customer  Recency  MntWines  ...  NumStorePurchases  \
# 2          1     5/13/14        0       134  ...                  5
# 10         0    12/27/13        0       450  ...                 10
# 11         0     12/9/13        0       140  ...                  6
# 13         0    10/16/13        0         3  ...                  2
# 14         1     10/5/13        0        16  ...                  0
#
#     NumWebVisitsMonth  AcceptedCmp3  AcceptedCmp4  AcceptedCmp5  AcceptedCmp1  \
# 2                   2             0             0             0             0
# 10                  1             0             0             0             0
# 11                  4             0             0             0             0
# 13                  6             0             0             0             0
# 14                  1             0             0             0             0
#
#     AcceptedCmp2  Response  Complain  Country
# 2              0         0         0       US
# 10             0         0         0       US
# 11             0         0         0       SP
# 13             0         0         0       CA
# 14             0         0         0       SP
#
# [5 rows x 28 columns]

# %%
df_zero = df.loc[df["Response"] == 0]
df_one = df.loc[df["Response"] == 1]

# %%
df_zero.head()
# Out:
#        ID  Year_Birth   Education Marital_Status      Income   Kidhome  \
# 2   10476        1958  Graduation        Married  $67,267.00         0
# 10   2079        1947    2n Cycle        Married  $81,044.00         0
# 11   5642        1979      Master       Together  $62,499.00         1
# 13   2964        1981  Graduation        Married  $26,872.00         0
# 14  10311        1969  Graduation        Married   $4,428.00         0
#
#     Teenhome Dt_Customer  Recency  MntWines  ...  NumStorePurchases  \
# 2          1     5/13/14        0       134  ...                  5
# 10         0    12/27/13        0       450  ...                 10
# 11         0     12/9/13        0       140  ...                  6
# 13         0    10/16/13        0         3  ...                  2
# 14         1     10/5/13        0        16  ...                  0
#
#     NumWebVisitsMonth  AcceptedCmp3  AcceptedCmp4  AcceptedCmp5  AcceptedCmp1  \
# 2                   2             0             0             0             0
# 10                  1             0             0             0             0
# 11                  4             0             0             0             0
# 13                  6             0             0             0             0
# 14                  1             0             0             0             0
#
#     AcceptedCmp2  Response  Complain  Country
# 2              0         0         0       US
# 10             0         0         0       US
# 11             0         0         0       SP
# 13             0         0         0       CA
# 14             0         0         0       SP
#
# [5 rows x 28 columns]

# %%
print(df1.shape, df0.shape)
# Out:
# (295, 28) (1537, 28)

# %%
df.to_csv('clean_marketing_data.csv', index=False)
